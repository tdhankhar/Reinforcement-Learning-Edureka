# %% [markdown]
# # MonteCarlo Control
#
# Control is the process of finding the best policy for a given environment. We follow generalised policy iteration and alternate between policy evaluation and policy improvement.

# %%
import numpy as np
from gridworld import GridWorld
np.set_printoptions(precision=3,suppress=True)

# %% [markdown]
# Return computation function now takes as input a list containing a 3-tuple (state,action,reward) and the discount factor gamma, the output is a value representing the return from that state.

# %%
def get_return(state_list, gamma):
    counter = 0
    return_value = 0
    for visit in state_list:
        reward = visit[2]
        return_value += reward * np.power(gamma, counter)
        counter += 1
    return return_value

# %% [markdown]
# Get a policy and improve it by taking a greedy action.

# %%
def improve_policy(episode_list, policy_matrix, state_action_matrix):
    
    for visit in episode_list:
        observation = visit[0]
        col = observation[1] + (observation[0]*4)
        if(policy_matrix[observation[0], observation[1]] != -1):      
            policy_matrix[observation[0], observation[1]] = np.argmax(state_action_matrix[:,col])
    return policy_matrix

# %% [markdown]
# 1.Lets create a grid world, the states marked 1 are terminal state and those marked -1 contain obstacles. <br>
# 2.The agent receives a reward of -0.04 for every move from non-terminal states <br>
# 3.The  actions are UP(0), RIGHT(1), DOWN(2) and LEFT(3)

# %%
env = GridWorld(3, 4)

#Define the state matrix
state_matrix = np.zeros((3,4))
state_matrix[0, 3] = 1
state_matrix[1, 3] = 1
state_matrix[1, 1] = -1
print("State Matrix:")
print(state_matrix)

#Define the reward matrix
reward_matrix = np.full((3,4), -0.04)
reward_matrix[0, 3] = 1
reward_matrix[1, 3] = -1
print("Reward Matrix:")
print(reward_matrix)

#Define the transition matrix
transition_matrix = np.array([[0.8, 0.1, 0.0, 0.1],
                              [0.1, 0.8, 0.1, 0.0],
                              [0.0, 0.1, 0.8, 0.1],
                              [0.1, 0.0, 0.1, 0.8]])

#Random policy
policy_matrix = np.random.randint(low=0, high=4, size=(3, 4)).astype(np.float32)
policy_matrix[1,1] = np.NaN #NaN for the obstacle at (1,1)
policy_matrix[0,3] = policy_matrix[1,3] = -1 #No action for the terminal states

#Set the matrices in the world
env.setStateMatrix(state_matrix)
env.setRewardMatrix(reward_matrix)
env.setTransitionMatrix(transition_matrix)
# Out:
# State Matrix:
# [[ 0.  0.  0.  1.]
#  [ 0. -1.  0.  1.]
#  [ 0.  0.  0.  0.]]
# Reward Matrix:
# [[-0.04 -0.04 -0.04  1.  ]
#  [-0.04 -0.04 -0.04 -1.  ]
#  [-0.04 -0.04 -0.04 -0.04]]

# %%
state_action_matrix = np.random.random_sample((4,12)) # Q
#init with 1.0e-10 to avoid division by zero
running_mean_matrix = np.full((4,12), 1.0e-10) 
gamma = 0.999
tot_epoch = 100000
print_epoch = 20

for epoch in range(tot_epoch):
    #Starting a new episode
    episode_list = list()
    #Reset and return the first observation and reward
    observation = env.reset(exploring_starts=True)
    #action = np.random.choice(4, 1)
    #action = policy_matrix[observation[0], observation[1]]
    #episode_list.append((observation, action, reward))
    is_starting = True
    for _ in range(1000):
        #Take the action from the action matrix
        action = policy_matrix[observation[0], observation[1]]
        #If the episode just started then it is
            #necessary to choose a random action (exploring starts)
        if(is_starting): 
            action = np.random.randint(0, 4)
            is_starting = False      
        #Move one step in the environment and get obs and reward
        new_observation, reward, done = env.step(action)
        #Append the visit in the episode list
        episode_list.append((observation, action, reward))
        observation = new_observation
        if done: break
    #The episode is finished, now estimating the utilities
    counter = 0
    #Checkup to identify if it is the first visit to a state
    checkup_matrix = np.zeros((4,12))
    #This cycle is the implementation of First-Visit MC.
    #For each state stored in the episode list check if it
    #is the rist visit and then estimate the return.
    for visit in episode_list:
        observation = visit[0]
        action = visit[1]
        col = int(observation[1] + (observation[0]*4))
        row = int(action)
        if(checkup_matrix[row, col] == 0):
            return_value = get_return(episode_list[counter:], gamma)
            running_mean_matrix[row, col] += 1
            state_action_matrix[row, col] += return_value
            checkup_matrix[row, col] = 1
        counter += 1
    #Policy Update
    policy_matrix = improve_policy(episode_list, 
                                  policy_matrix, 
                                  state_action_matrix/running_mean_matrix)
    #Printing
    if(epoch % print_epoch == 0):
        print("")
        #print("State-Action matrix after " + str(epoch+1) + " iterations:") 
        #print(state_action_matrix / running_mean_matrix)
        print("Policy matrix after " + str(epoch+1) + " iterations:") 
        print(policy_matrix)
        
#Time to check the value  matrix obtained
print("value matrix after " + str(tot_epoch) + " iterations:")
print(state_action_matrix / running_mean_matrix)

print("Policy matrix after " + str(epoch+1) + " iterations:") 
print(policy_matrix)
# Out:
# Policy matrix after 1 iterations:
# [[ 0.  2.  2. -1.]
#  [ 2. nan  0. -1.]
#  [ 2.  0.  0.  3.]]
#
# Policy matrix after 21 iterations:
# [[ 1.  0.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  1.]]
#
# Policy matrix after 41 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  0.]]
#
# Policy matrix after 61 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  0.]]
#
# Policy matrix after 81 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  0.]]
#
# Policy matrix after 101 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  0.]]
#
# Policy matrix after 121 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 141 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 161 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 181 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 201 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 221 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 241 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 261 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 281 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 301 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 321 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 341 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 361 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 381 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 401 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 421 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 441 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 461 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 481 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 501 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 521 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 541 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 561 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 581 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 601 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 621 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 641 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 661 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 681 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 701 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 721 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 741 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 761 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 781 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 801 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 821 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 841 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 861 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 881 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 901 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 921 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 941 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 961 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 981 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1001 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1021 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1041 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1061 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1081 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1101 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1121 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1141 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1161 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1181 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1201 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1221 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1241 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1261 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1281 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1301 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1321 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1341 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1361 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1381 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1401 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1421 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1441 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1461 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1481 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1501 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1521 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1541 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1561 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1581 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1601 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1621 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1641 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1661 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1681 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1701 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1721 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1741 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1761 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1781 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1801 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1821 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1841 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1861 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1881 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1901 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1921 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1941 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1961 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 1981 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 2001 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 2021 iterations:
# [[ 1.  1.  1. -1.]
#  [ 0. nan  0. -1.]
#  [ 0.  2.  0.  3.]]
#
# Policy matrix after 